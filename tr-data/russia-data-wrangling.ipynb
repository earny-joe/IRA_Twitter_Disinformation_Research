# %%
import pandas as pd
pd.set_option("display.max_columns", None)

dtype = {
    "tweetid": str
}

# creater object for iteration with chunksize of 50,000 observations
chunks = pd.read_csv(
    "russian_linked_tweets_csv_hashed.csv", 
    chunksize=50000,
    dtype=dtype,
    low_memory=False)

# %%
from tqdm import tqdm

# empty list to store chunks
chunk_list = []

# iterate through chunks, appending to list
for chunk in tqdm(chunks):
    chunk_list.append(chunk)
    
# concat list into dataframe
df = pd.concat(chunk_list)
# Out:
# 19it [00:07,  2.38it/s]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 920761 entries, 0 to 920760
# Data columns (total 31 columns):
# tweetid                     920761 non-null object
# userid                      920761 non-null object
# user_display_name           920761 non-null object
# user_screen_name            920761 non-null object
# user_reported_location      912810 non-null object
# user_profile_description    901370 non-null object
# user_profile_url            329438 non-null object
# follower_count              920761 non-null int64
# following_count             920761 non-null int64
# account_creation_date       920761 non-null object
# account_language            920761 non-null object
# tweet_language              918184 non-null object
# tweet_text                  920761 non-null object
# tweet_time                  920761 non-null object
# tweet_client_name           920761 non-null object
# in_reply_to_userid          76106 non-null object
# in_reply_to_tweetid         72380 non-null float64
# quoted_tweet_tweetid        118087 non-null float64
# is_retweet                  920761 non-null bool
# retweet_userid              712800 non-null object
# retweet_tweetid             712800 non-null float64
# latitude                    920761 non-null object
# longitude                   920761 non-null object
# quote_count                 914726 non-null float64
# reply_count                 914726 non-null float64
# like_count                  914726 non-null float64
# retweet_count               914726 non-null float64
# hashtags                    907427 non-null object
# urls                        903876 non-null object
# user_mentions               911084 non-null object
# poll_choices                0 non-null float64
# dtypes: bool(1), float64(8), int64(2), object(20)
# memory usage: 211.6+ MB

# %%
df.head()
# Out:
#               tweetid                                        userid  \
# 0  894109669869985793                                    4125840934
# 1  839851611656761344                                    4125840934
# 2  841662351510249472                                    4125840934
# 3  820599201495187456                                    4125840934
# 4  549829105483808768  EjLn9BPgSPWKPhEnebvOIWJ2quALQVMNPVfFgGyzG+8=
#
#                               user_display_name  \
# 0                               Inside Syria MC
# 1                               Inside Syria MC
# 2                               Inside Syria MC
# 3                               Inside Syria MC
# 4  EjLn9BPgSPWKPhEnebvOIWJ2quALQVMNPVfFgGyzG+8=
#
#                                user_screen_name user_reported_location  \
# 0                                  Inside_Syria                  Syria
# 1                                  Inside_Syria                  Syria
# 2                                  Inside_Syria                  Syria
# 3                                  Inside_Syria                  Syria
# 4  EjLn9BPgSPWKPhEnebvOIWJ2quALQVMNPVfFgGyzG+8=          New York, USA
#
#                             user_profile_description         user_profile_url  \
# 0  Collecting information about the Syrian confli...  https://t.co/x9PTLhaz76
# 1  Collecting information about the Syrian confli...  https://t.co/x9PTLhaz76
# 2  Collecting information about the Syrian confli...  https://t.co/x9PTLhaz76
# 3  Collecting information about the Syrian confli...  https://t.co/x9PTLhaz76
# 4                                        experienced                      NaN
#
#    follower_count  following_count account_creation_date account_language  \
# 0           19816              808            2015-11-06               en
# 1           19816              808            2015-11-06               en
# 2           19816              808            2015-11-06               en
# 3           19816              808            2015-11-06               en
# 4             129              194            2014-05-30               en
#
#   tweet_language                                         tweet_text  \
# 0             en  New Convoy of #SyrianArmy Arrived in #Hama #In...
# 1             ar  الجيش السوري يتقدم في محيط حلب #سورية_النظر_من...
# 2             ar  #الجعفري: نحن حريصون كل الحرص على إنجاح مسار #...
# 3             en  #Iraq:\nMore than 30 civilians killed in a U.@...
# 4             en  Those who truly know me, know that my true pay...
#
#          tweet_time   tweet_client_name in_reply_to_userid  \
# 0  2017-08-06 08:15       WordPress.com                NaN
# 1  2017-03-09 14:53       WordPress.com                NaN
# 2  2017-03-14 14:48       WordPress.com                NaN
# 3  2017-01-15 11:51  Twitter Web Client                NaN
# 4  2014-12-30 07:27  Twitter Web Client                NaN
#
#    in_reply_to_tweetid  quoted_tweet_tweetid  is_retweet retweet_userid  \
# 0                  NaN                   NaN       False            NaN
# 1                  NaN                   NaN       False            NaN
# 2                  NaN                   NaN       False            NaN
# 3                  NaN                   NaN       False            NaN
# 4                  NaN                   NaN       False            NaN
#
#    retweet_tweetid latitude longitude  quote_count  reply_count  like_count  \
# 0              NaN   absent    absent          0.0          0.0         0.0
# 1              NaN   absent    absent          0.0          0.0         0.0
# 2              NaN   absent    absent          0.0          0.0         0.0
# 3              NaN   absent    absent          0.0          0.0         1.0
# 4              NaN   absent    absent          0.0          0.0         0.0
#
#    retweet_count                                        hashtags  \
# 0            0.0         ['SyrianArmy', 'Hama', 'InsideSyriaMC']
# 1            0.0                       ['سورية_النظر_من_الداخل']
# 2            0.0  ['الجعفري', 'أستانا', 'سورية_النظر_من_الداخل']
# 3            0.0                           ['Iraq', 'airstrike']
# 4            0.0                                             NaN
#
#                                                 urls user_mentions  \
# 0  ['http://en.insidesyriamc.com/2017/08/06/new-c...            []
# 1  ['http://insidesyriamc.com/2017/03/09/%d8%a7%d...            []
# 2  ['http://insidesyriamc.com/2017/03/14/%d8%a7%d...            []
# 3                                                 []  [2876420003]
# 4                                                NaN           NaN
#
#    poll_choices
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN

# %%
# generate list of columns
list(df.columns)
# Out:
# ['tweetid',
#  'userid',
#  'user_display_name',
#  'user_screen_name',
#  'user_reported_location',
#  'user_profile_description',
#  'user_profile_url',
#  'follower_count',
#  'following_count',
#  'account_creation_date',
#  'account_language',
#  'tweet_language',
#  'tweet_text',
#  'tweet_time',
#  'tweet_client_name',
#  'in_reply_to_userid',
#  'in_reply_to_tweetid',
#  'quoted_tweet_tweetid',
#  'is_retweet',
#  'retweet_userid',
#  'retweet_tweetid',
#  'latitude',
#  'longitude',
#  'quote_count',
#  'reply_count',
#  'like_count',
#  'retweet_count',
#  'hashtags',
#  'urls',
#  'user_mentions',
#  'poll_choices']

# %% [markdown]
# There is a lot of information here. For the purposes of this project -- and to keep things as uniform as possible between the Verified and Russian data sets -- we'll only use a portion of these columns. Namely, we'll use:
# - `tweetid` (represented by `id_str` in Verified account data)
# - `user_screen_name` (represented by `screen_name` in Verified account data)
# - `tweet_time` (represented by `created_at` in Verified account data)
# - `tweet_language` (represented by `lang` in Verified account data)
# - `tweet_client_name` (represented by `source` in Verified account data)
# - `retweet_count`
# - `like_count` (represented by `favorite_count` in Verified account data)
# - `tweet_text` (represented by `full_text` in Verified account data)

# %%
cols_interest = [
    "tweetid",
    "user_screen_name",
    "tweet_time",
    "tweet_language",
    "tweet_client_name",
    "retweet_count",
    "like_count",
    "tweet_text"
]

# grab only columns we're interested in
df = df[cols_interest].copy()

# %%
df.head()
# Out:
#               tweetid                              user_screen_name  \
# 0  894109669869985793                                  Inside_Syria
# 1  839851611656761344                                  Inside_Syria
# 2  841662351510249472                                  Inside_Syria
# 3  820599201495187456                                  Inside_Syria
# 4  549829105483808768  EjLn9BPgSPWKPhEnebvOIWJ2quALQVMNPVfFgGyzG+8=
#
#          tweet_time tweet_language   tweet_client_name  retweet_count  \
# 0  2017-08-06 08:15             en       WordPress.com            0.0
# 1  2017-03-09 14:53             ar       WordPress.com            0.0
# 2  2017-03-14 14:48             ar       WordPress.com            0.0
# 3  2017-01-15 11:51             en  Twitter Web Client            0.0
# 4  2014-12-30 07:27             en  Twitter Web Client            0.0
#
#    like_count                                         tweet_text
# 0         0.0  New Convoy of #SyrianArmy Arrived in #Hama #In...
# 1         0.0  الجيش السوري يتقدم في محيط حلب #سورية_النظر_من...
# 2         0.0  #الجعفري: نحن حريصون كل الحرص على إنجاح مسار #...
# 3         1.0  #Iraq:\nMore than 30 civilians killed in a U.@...
# 4         0.0  Those who truly know me, know that my true pay...

# %% [markdown]
# Looks like this data set contains other languages. Lets see the breakdown by each using the `tweet_language` column.

# %%
# convert tweet_language column to category type
df["tweet_language"] = df["tweet_language"].astype("category")

# %%
# get the value counts for top 10 languages
round(df["tweet_language"].value_counts(normalize=True) * 100, 4)[:10]
# Out:
# en     80.7741
# und    16.2598
# fr      0.9499
# ru      0.7810
# ar      0.2129
# es      0.1675
# in      0.1233
# tr      0.0990
# tl      0.0737
# de      0.0673
# Name: tweet_language, dtype: float64

# %% [markdown]
# Looks like the vast majority of observations are in English or are undefined (i.e., `und`). Let's see if we might be able to reclassify these undefined observations using [`googletrans`](https://github.com/ssut/py-googletrans).

# %%
# install googletrans library (if needed)
#!pip install googletrans

# %%
from googletrans import Translator

# instantiate translator object
translator = Translator()

# %%
# grab observations with und tweet language
undefined = df[df["tweet_language"] == "und"]
undefined[:3]
# Out:
#                tweetid                              user_screen_name  \
# 5   548749959605280769  yjxwJBdqQgtGbJIozVTuYw23B+DY557Nz8lZeJ4jsJg=
# 11  846188781770190848                                    SamInfidel
# 19  584085161253281792                               CathyTo47590555
#
#           tweet_time tweet_language    tweet_client_name  retweet_count  \
# 5   2014-12-27 07:59            und  Twitter for Android            0.0
# 11  2017-03-27 02:35            und   Twitter for iPhone            1.0
# 19  2015-04-03 20:08            und   Twitter for iPhone            0.0
#
#     like_count                                         tweet_text
# 5          0.0                             http://t.co/WU6zpuKdjE
# 11         0.0  #SuddenJihadSyndrome #ReligionOfShit #BanTheQu...
# 19         0.0                             http://t.co/qlJAXUnjTn

# %%
#undefined["tweet_text"][:5].map(translator.detect).apply(getattr, args=("lang"))

# %% [markdown]
# Due to consistent errors when trying to detect the language, we'll just drop all observations except those in English. Yes, this eliminates quite a bit of data however, since all our Verified data is in English, I think this is the best route to go. Additionally, using only English to start out decreases the complexity by not having to do any translation, and we're not even sure if we'll be able to build a good model in the first place.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 920761 entries, 0 to 920760
# Data columns (total 8 columns):
# tweetid              920761 non-null object
# user_screen_name     920761 non-null object
# tweet_time           920761 non-null object
# tweet_language       918184 non-null category
# tweet_client_name    920761 non-null object
# retweet_count        914726 non-null float64
# like_count           914726 non-null float64
# tweet_text           920761 non-null object
# dtypes: category(1), float64(2), object(5)
# memory usage: 50.1+ MB

# %%
# grab subset of observations that are only in english
english = df[df["tweet_language"] == "en"]

# %%
english.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 741655 entries, 0 to 920760
# Data columns (total 8 columns):
# tweetid              741655 non-null object
# user_screen_name     741655 non-null object
# tweet_time           741655 non-null object
# tweet_language       741655 non-null category
# tweet_client_name    741655 non-null object
# retweet_count        736139 non-null float64
# like_count           736139 non-null float64
# tweet_text           741655 non-null object
# dtypes: category(1), float64(2), object(5)
# memory usage: 46.0+ MB
